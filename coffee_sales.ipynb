# %% [markdown]
# # <font color="Red" >Coffee Sales Analysis Using Pandas

# %% [markdown]
# - The dataset used in this analysis is sourced from Kaggle and focuses on coffee sales, available at the following link:
#
# ## <a href="https://www.kaggle.com/datasets/ahmedabbas757/coffee-sales/data">KAGGLE Data Link</a>
# - This dataset provides comprehensive information on transactions involving various types of coffee products across different store locations.
#
# - It includes fields such as transaction details (date, time, quantity), store identifiers, product specifics (ID, category, type), unit prices, and more. Analyzing this dataset enables insights into revenue trends, popular products, pricing strategies, and store performance, offering valuable opportunities for sales optimization and market understanding in the coffee industry.

# %% [markdown]
# import pandas as pd

# %%
df=pd.read_excel("datasets/coffee_sales.xlsx")
df
# Out:
#         transaction_id transaction_date transaction_time  transaction_qty  \
# 0                    1       2023-01-01         07:06:11                2
# 1                    2       2023-01-01         07:08:56                2
# 2                    3       2023-01-01         07:14:04                2
# 3                    4       2023-01-01         07:20:24                1
# 4                    5       2023-01-01         07:22:41                2
# ...                ...              ...              ...              ...
# 149111          149452       2023-06-30         20:18:41                2
# 149112          149453       2023-06-30         20:25:10                2
# 149113          149454       2023-06-30         20:31:34                1
# 149114          149455       2023-06-30         20:57:19                1
# 149115          149456       2023-06-30         20:57:19                2
#
#         store_id   store_location  product_id  unit_price    product_category  \
# ...

# %% [markdown]
# ## To show top 5 records in a dataframe

# %%
df.head()
# Out:
#    transaction_id transaction_date transaction_time  transaction_qty  \
# 0               1       2023-01-01         07:06:11                2
# 1               2       2023-01-01         07:08:56                2
# 2               3       2023-01-01         07:14:04                2
# 3               4       2023-01-01         07:20:24                1
# 4               5       2023-01-01         07:22:41                2
#
#    store_id   store_location  product_id  unit_price    product_category  \
# 0         5  Lower Manhattan          32         3.0              Coffee
# 1         5  Lower Manhattan          57         3.1                 Tea
# 2         5  Lower Manhattan          59         4.5  Drinking Chocolate
# 3         5  Lower Manhattan          22         2.0              Coffee
# 4         5  Lower Manhattan          57         3.1                 Tea
#
#             product_type               product_detail
# 0  Gourmet brewed coffee                  Ethiopia Rg
# ...

# %% [markdown]
# ## To show bottom 5 records in  a dataframe

# %%
df.tail()
# Out:
#         transaction_id transaction_date transaction_time  transaction_qty  \
# 149111          149452       2023-06-30         20:18:41                2
# 149112          149453       2023-06-30         20:25:10                2
# 149113          149454       2023-06-30         20:31:34                1
# 149114          149455       2023-06-30         20:57:19                1
# 149115          149456       2023-06-30         20:57:19                2
#
#         store_id  store_location  product_id  unit_price product_category  \
# 149111         8  Hell's Kitchen          44        2.50              Tea
# 149112         8  Hell's Kitchen          49        3.00              Tea
# 149113         8  Hell's Kitchen          45        3.00              Tea
# 149114         8  Hell's Kitchen          40        3.75           Coffee
# 149115         8  Hell's Kitchen          64        0.80         Flavours
#
#              product_type        product_detail
# ...

# %% [markdown]
# ## How many transaction are recorded in the datasets

# %%
print("The total transaction are recorded in the datasets is =",df.shape[0])
# Out:
# The total transaction are recorded in the datasets is = 149116

# %% [markdown]
# ## To show columns names in the dataframe

# %%
df.columns
# Out:
# Index(['transaction_id', 'transaction_date', 'transaction_time',
#        'transaction_qty', 'store_id', 'store_location', 'product_id',
#        'unit_price', 'product_category', 'product_type', 'product_detail'],
#       dtype='object')

# %%
for i in df.columns:
    print(i)
# Out:
# transaction_id
# transaction_date
# transaction_time
# transaction_qty
# store_id
# store_location
# product_id
# unit_price
# product_category
# product_type
# product_detail

# %% [markdown]
# ## To show the datatype of each columns

# %%
df.dtypes
# Out:
# transaction_id               int64
# transaction_date    datetime64[ns]
# transaction_time            object
# transaction_qty              int64
# store_id                     int64
# store_location              object
# product_id                   int64
# unit_price                 float64
# product_category            object
# product_type                object
# product_detail              object
# dtype: object

# %% [markdown]
# ## To Check the missing value in datasets

# %%
df.isnull().sum()
# Out:
# transaction_id      0
# transaction_date    0
# transaction_time    0
# transaction_qty     0
# store_id            0
# store_location      0
# product_id          0
# unit_price          0
# product_category    0
# product_type        0
# product_detail      0
# dtype: int64

# %% [markdown]
# ## Calculate sum(transaction_qty) of with each product category

# %%
df.pivot_table(index='product_category',values='transaction_qty',aggfunc='sum')
# Out:
#                     transaction_qty
# product_category
# Bakery                        23214
# Branded                         776
# Coffee                        89250
# Coffee beans                   1828
# Drinking Chocolate            17457
# Flavours                      10511
# Loose Tea                      1210
# Packaged Chocolate              487
# Tea                           69737

# %% [markdown]
# ## To find sum of transaction quantity with store_loation

# %%
df.groupby(by='store_location')[['transaction_qty']].sum()
# Out:
#                  transaction_qty
# store_location
# Astoria                    70991
# Hell's Kitchen             71737
# Lower Manhattan            71742

# %%
result_df=df.groupby(by='store_location')[['transaction_qty']].sum()

# %%
import matplotlib.pyplot as plt
colors = ['red', 'green','blue']
plt.figure(figsize=(8,5))
plt.xlabel("Store Location",fontsize=15,color='red')
plt.ylabel("Transaction Quantity",fontsize=15,color='red')
plt.bar(result_df.index,result_df['transaction_qty'],color=colors,width=0.5)
plt.show()

# %% [markdown]
# ## What is the average unit price of the products sold?

# %%
df['unit_price'].mean()
# Out:
# 3.382219413074385

# %% [markdown]
# ## Find some statistical analyis from the datasets

# %%
df.describe()
# Out:
#        transaction_id               transaction_date  transaction_qty  \
# count   149116.000000                         149116    149116.000000
# mean     74737.371872  2023-04-15 11:50:32.173609984         1.438276
# min          1.000000            2023-01-01 00:00:00         1.000000
# 25%      37335.750000            2023-03-06 00:00:00         1.000000
# 50%      74727.500000            2023-04-24 00:00:00         1.000000
# 75%     112094.250000            2023-05-30 00:00:00         2.000000
# max     149456.000000            2023-06-30 00:00:00         8.000000
# std      43153.600016                            NaN         0.542509
#
#             store_id     product_id     unit_price
# count  149116.000000  149116.000000  149116.000000
# mean        5.342063      47.918607       3.382219
# min         3.000000       1.000000       0.800000
# 25%         3.000000      33.000000       2.500000
# 50%         5.000000      47.000000       3.000000
# ...

# %%
df.head()
# Out:
#    transaction_id transaction_date transaction_time  transaction_qty  \
# 0               1       2023-01-01         07:06:11                2
# 1               2       2023-01-01         07:08:56                2
# 2               3       2023-01-01         07:14:04                2
# 3               4       2023-01-01         07:20:24                1
# 4               5       2023-01-01         07:22:41                2
#
#    store_id   store_location  product_id  unit_price    product_category  \
# 0         5  Lower Manhattan          32         3.0              Coffee
# 1         5  Lower Manhattan          57         3.1                 Tea
# 2         5  Lower Manhattan          59         4.5  Drinking Chocolate
# 3         5  Lower Manhattan          22         2.0              Coffee
# 4         5  Lower Manhattan          57         3.1                 Tea
#
#             product_type               product_detail
# 0  Gourmet brewed coffee                  Ethiopia Rg
# ...

# %% [markdown]
# ## Calculate the  total Revenue generated  by Store location

# %%
df['revenue']=df['transaction_qty']*df['unit_price']

# %%
result_df=df.groupby(by='product_category')[['revenue']].sum()

# %%
color=['green', 'orange', 'blue','purple','red','yellow','orangered','violet','black']
plt.xlabel("Total Revenue",color='red',fontsize=20)
plt.ylabel("Store Location",color='red',fontsize=20)
plt.barh(result_df.index,result_df['revenue'],color=color)
plt.show()

# %%
df.head()
# Out:
#    transaction_id transaction_date transaction_time  transaction_qty  \
# 0               1       2023-01-01         07:06:11                2
# 1               2       2023-01-01         07:08:56                2
# 2               3       2023-01-01         07:14:04                2
# 3               4       2023-01-01         07:20:24                1
# 4               5       2023-01-01         07:22:41                2
#
#    store_id   store_location  product_id  unit_price    product_category  \
# 0         5  Lower Manhattan          32         3.0              Coffee
# 1         5  Lower Manhattan          57         3.1                 Tea
# 2         5  Lower Manhattan          59         4.5  Drinking Chocolate
# 3         5  Lower Manhattan          22         2.0              Coffee
# 4         5  Lower Manhattan          57         3.1                 Tea
#
#             product_type               product_detail  revenue
# ...

# %%
df.dtypes
# Out:
# transaction_id               int64
# transaction_date    datetime64[ns]
# transaction_time            object
# transaction_qty              int64
# store_id                     int64
# store_location              object
# product_id                   int64
# unit_price                 float64
# product_category            object
# product_type                object
# product_detail              object
# revenue                    float64
# dtype: object

# %% [markdown]
# ##  Add a Year Column in a datasets

# %%
df['Year']=df.transaction_date.dt.year

# %% [markdown]
# ## Add a Month Column in datasets

# %%
df['Month']=df.transaction_date.dt.month_name()

# %%
df.tail()
# Out:
#         transaction_id transaction_date transaction_time  transaction_qty  \
# 149111          149452       2023-06-30         20:18:41                2
# 149112          149453       2023-06-30         20:25:10                2
# 149113          149454       2023-06-30         20:31:34                1
# 149114          149455       2023-06-30         20:57:19                1
# 149115          149456       2023-06-30         20:57:19                2
#
#         store_id  store_location  product_id  unit_price product_category  \
# 149111         8  Hell's Kitchen          44        2.50              Tea
# 149112         8  Hell's Kitchen          49        3.00              Tea
# 149113         8  Hell's Kitchen          45        3.00              Tea
# 149114         8  Hell's Kitchen          40        3.75           Coffee
# 149115         8  Hell's Kitchen          64        0.80         Flavours
#
#              product_type        product_detail  revenue  Year Month
# ...

# %% [markdown]
# ## Calculate Month Wise Total Revenue and Total transaction quantity

# %%
month=['January','February','March','April','May','June']
res_df=df.pivot_table(index='Month',values=['revenue','transaction_qty'],aggfunc='sum')
res_df.loc[month]
# Out:
#             revenue  transaction_qty
# Month
# January    81677.74            24870
# February   76145.19            23550
# March      98834.68            30406
# April     118941.08            36469
# May       156727.76            48233
# June      166485.88            50942
